# %%
#Necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fbprophet import Prophet
import requests
import datetime
from bs4 import BeautifulSoup
# %matplotlib inline

#Turn off chained assignment warnings
pd.options.mode.chained_assignment = None  # default='warn'

# %%
r = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2016")
soup = BeautifulSoup(r.content, 'lxml')
table = soup.find_all("table")[1]
movies_2016_1 = pd.read_html(str(table))[0]

r = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2016/101")
soup = BeautifulSoup(r.content, 'lxml')
table = soup.find_all("table")[1]
movies_2016_101 = pd.read_html(str(table))[0]

r = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2017")
soup = BeautifulSoup(r.content, 'lxml')
table = soup.find_all("table")[1]
movies_2017_1 = pd.read_html(str(table))[0]

r = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2017/101")
soup = BeautifulSoup(r.content, 'lxml')
table = soup.find_all("table")[1]
movies_2017_101 = pd.read_html(str(table))[0]

r = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2018")
soup = BeautifulSoup(r.content, 'lxml')
table = soup.find_all("table")[1]
movies_2018 = pd.read_html(str(table))[0]

past_data = pd.concat([movies_2016_1,movies_2016_101,movies_2017_1,movies_2017_101, movies_2018], ignore_index=True)

past_data.shape
past_data.head()
# Out:
#    Rank                         Movie DomesticBoxOffice  OpeningTheaterCount  \
# 0     1  Rogue One: A Star Wars Story      $532,177,324                 4157
# 1     2                  Finding Dory      $486,295,561                 4305
# 2     3    Captain America: Civil War      $408,084,349                 4226
# 3     4       The Secret Life of Pets      $368,384,330                 4370
# 4     5               The Jungle Book      $364,001,123                 4028
#
#   OpeningWeekendBox Office  MaxTheaterCount
# 0             $155,081,681             4157
# 1             $135,060,273             4305
# 2             $179,139,142             4226
# 3             $104,352,905             4381
# 4             $103,261,464             4144

# %%
def clean_table(soup):
    try:
        table = soup.find_all("table", id = False)[1]
        summary = pd.read_html(str(table))[0]
        
        #clean the values
        summary.loc[:,0] = summary.loc[:,0].str.strip(':')
        summary.loc[:,0] = summary.loc[:,0].str.replace('\xa0',' ')
        summary.loc[:,1] = summary.loc[:,1].str.replace('[$:,\.()]+','')
        
        #Transpose the data_frame, do more cleaning...
        summary_T = summary.set_index(0).transpose()
        summary_T["Domestic Releases"] = summary_T["Domestic Releases"].str.replace('(?<=2016|2017|2018).*','')
        summary_T["MPAA Rating"] = summary_T["MPAA Rating"].str.extract('(PG-13|R|G|NC-17|PG)', expand = False)
        summary_T["Running Time"] = summary_T["Running Time"].str.extract('(\d+)', expand = False)
        summary_T["Production Companies"] = summary_T["Production Companies"].str.extract('(^\S*)', expand = False)
        cols = ["Production Budget", "Domestic Releases", "MPAA Rating", "Running Time", "Franchise",
               "Source", "Genre", "Production Method", "Creative Type", "Production Companies", "Production Countries"]
        summary_T = summary_T.loc[:,cols]
        summary_T
    except KeyError:
        table = soup.find_all("table", id = False)[0]
        summary = pd.read_html(str(table))[0]
        
        #clean the values
        summary.loc[:,0] = summary.loc[:,0].str.strip(':')
        summary.loc[:,0] = summary.loc[:,0].str.replace('\xa0',' ')
        summary.loc[:,1] = summary.loc[:,1].str.replace('[$:,\.()]+','')
        
        #Transpose the data_frame, do more cleaning...
        summary_T = summary.set_index(0).transpose()
        summary_T["Domestic Releases"] = summary_T["Domestic Releases"].str.replace('(?<=2016|2017|2018).*','')
        summary_T["MPAA Rating"] = summary_T["MPAA Rating"].str.extract('(PG-13|R|G|NC-17|PG)', expand = False)
        summary_T["Running Time"] = summary_T["Running Time"].str.extract('(\d+)', expand = False)
        summary_T["Production Companies"] = summary_T["Production Companies"].str.extract('(^\S*)', expand = False)
        cols = ["Production Budget", "Domestic Releases", "MPAA Rating", "Running Time", "Franchise",
               "Source", "Genre", "Production Method", "Creative Type", "Production Companies", "Production Countries"]
        summary_T = summary_T.loc[:,cols]
        summary_T
    return summary_T

# %%
def get_content(row):
    try:
        r = requests.get("https://www.the-numbers.com/movie/{}-(2018)".format(row))
        soup = BeautifulSoup(r.content, 'lxml')
        table = soup.find_all(id = 'box_office_chart')[1]
        print("Found and stored data for {}-2018!".format(row))
        return soup
    except IndexError: #the-numbers.com sometimes includes movie year, sometimes does not
        print("No luck finding {}-(2018), will try adding -(2017)".format(row))
        try:
            r = requests.get("https://www.the-numbers.com/movie/{}-(2017)".format(row))
            soup = BeautifulSoup(r.content, 'lxml')
            table = soup.find_all(id = 'box_office_chart')[1]
            print("Found and stored data for {}-2017!".format(row))
            return soup
        except IndexError: #the-numbers.com sometimes includes movie year, sometimes does not
            print("No luck finding {}-(2017), will try adding -(2016)".format(row))
            try:
                r = requests.get("https://www.the-numbers.com/movie/{}-(2016)".format(row))
                soup = BeautifulSoup(r.content, 'lxml')
                table = soup.find_all(id = 'box_office_chart')[1]
                print("Found and stored data for {}-2016!".format(row))
                return soup
            except IndexError: #the-numbers.com mislabeled "Moonlight" as from 2015...
                print("No luck finding {}-(2016) either. Will try adding -(2015).".format(row))
                try:
                    r = requests.get("https://www.the-numbers.com/movie/{}-(2015)".format(row))
                    soup = BeautifulSoup(r.content, 'lxml')
                    table = soup.find_all(id = 'box_office_chart')[1]
                    print("Found and stored data for {}!".format(row))
                    return soup
                except IndexError: 
                    print("No luck finding {}-(2015) either. Will try removing year specification.".format(row))
                    try:
                        r = requests.get("https://www.the-numbers.com/movie/{}".format(row))
                        soup = BeautifulSoup(r.content, 'lxml')
                        table = soup.find_all(id = 'box_office_chart')[1]
                        print("Found and stored data for {}!".format(row))
                        return soup
                    except IndexError:
                        print(repr("Looks like {} doesn't exist on the-numbers.com. Try a google search?".format(row)))

# %%
past_data["url_part"] = past_data["Movie"]

the_mask = past_data["url_part"].str.startswith("The ")
past_data.loc[the_mask, "url_part"] = past_data.loc[the_mask, "url_part"].str.replace("^The ","") + " The" #Move "The" to end
past_data["url_part"] = past_data["url_part"].str.replace(' ', '-')

#colons with a space after are removed (as in "Jumani: "), and other string cleaning
past_data["url_part"] = past_data["url_part"].str.replace('[: ]+','')
#some other common characters will be removed in the-numbers.com URLs
past_data["url_part"] = past_data["url_part"].str.replace('[,!.\'â\x80\x99]+','')
#colons within words or numbers (as in "15:17") are replaced with dashes
past_data["url_part"] = past_data["url_part"].str.replace(':', '-')
#& is replaced with "and"
past_data["url_part"] = past_data["url_part"].str.replace('&', 'and')
past_data = past_data[past_data.Movie.str.contains("Negro") == False] # no company listed
past_data = past_data[past_data.Movie.str.contains("Katwe") == False] # no company listed
past_data = past_data[past_data.Movie.str.contains("Crusoe") == False] # no company listed

past_data
# Out:
#      Rank                                             Movie DomesticBoxOffice  \
# 0       1                      Rogue One: A Star Wars Story      $532,177,324
# 1       2                                      Finding Dory      $486,295,561
# 2       3                        Captain America: Civil War      $408,084,349
# 3       4                           The Secret Life of Pets      $368,384,330
# 4       5                                   The Jungle Book      $364,001,123
# 5       6                                          Deadpool      $363,070,709
# 6       7                                          Zootopia      $341,268,248
# 7       8                Batman v Superman: Dawn of Justice      $330,360,194
# 8       9                                     Suicide Squad      $325,100,054
# 9      10                                              Sing      $270,329,045
# 10     11                                             Moana      $248,757,044
# 11     12           Fantastic Beasts and Where to Find Them      $234,037,575
# 12     13                                    Doctor Strange      $232,641,920
# 13     14                                    Hidden Figures      $169,607,287
# 14     15                                      Jason Bourne      $162,192,920
# 15     16                                  Star Trek Beyond      $158,848,340
# 16     17                                 X-Men: Apocalypse      $155,442,489
# 17     18                                            Trolls      $153,707,064
# 18     19                                        La La Land      $151,101,803
# 19     20                                   Kung Fu Panda 3      $143,528,619
# 20     21                                      Ghostbusters      $128,350,574
# 21     22                              Central Intelligence      $127,440,871
# 22     23                              The Legend of Tarzan      $126,643,061
# 23     24                                             Sully      $125,070,033
# 24     25                                          Bad Moms      $113,257,297
# 25     26                             The Angry Birds Movie      $107,509,366
# 26     27                      Independence Day: Resurgence      $103,144,286
# 27     28          The Conjuring 2: The Enfield Poltergeist      $102,470,008
# 28     29                                           Arrival      $100,546,139
# 29     30                                        Passengers      $100,014,699
# ..    ...                                               ...               ...
# 456    57                           Sanpo Suru Shinryakusha           $35,372
# 457    58                                      Tehran Taboo           $31,601
# 458    59                                         A Ciambra           $30,988
# 459    60                        Memorias del subdesarrollo           $29,647
# 460    61               24 Frames: Before and After Lumiere           $26,855
# 461    62                                     Ridge Runners           $26,019
# 462    63                                           Western           $23,026
# 463    64                                           Vazante           $18,877
# 464    65                                        Freak Show           $18,216
# 465    66                                        Desolation           $16,920
# 466    67                                  The Female Brain           $16,273
# 467    68                                         Mind Game           $14,811
# 468    69                                          Oh Lucy!           $14,569
# 469    70                                The Boy Downstairs           $13,638
# 470    71                                           Like Me           $12,965
# 471    72                                            My Art           $12,554
# 472    73            The Wedding Party 2: Destination Dubai           $11,140
# 473    74                                       Death House           $10,295
# 474    75                                   Please Stand By            $9,868
# 475    76                                       Mama Africa            $9,808
# 476    77                                         The Cured            $9,306
# 477    78                       In the Land of Pomegranates            $7,014
# 478    79                                          November            $6,016
# 479    80                               Shan zhong zhuan qi            $4,592
# 480    81                                          Kangaroo            $4,547
# 481    82                            Kickboxer: Retaliation            $4,537
# 482    83  American Socialist: The Life & Times of Eugene …            $2,823
# 483    84                                          Souvenir            $2,267
# 484    85                                  The Cage Fighter            $2,027
# 485    86                          West of the Jordan River            $1,926
#
#      OpeningTheaterCount OpeningWeekendBox Office  MaxTheaterCount  \
# 0                   4157             $155,081,681             4157
# 1                   4305             $135,060,273             4305
# 2                   4226             $179,139,142             4226
# 3                   4370             $104,352,905             4381
# 4                   4028             $103,261,464             4144
# 5                   3558             $132,434,639             3856
# 6                   3827              $75,063,401             3959
# 7                   4242             $166,007,347             4256
# 8                   4255             $133,682,248             4255
# 9                   4022              $35,258,145             4029
# 10                  3875              $56,631,401             3875
# 11                  4144              $74,403,387             4144
# 12                  3882              $85,058,311             3882
# 13                    25                 $515,499             3416
# 14                  4026              $59,215,365             4039
# 15                  3928              $59,253,211             3928
# 16                  4150              $65,769,562             4153
# 17                  4060              $46,581,142             4066
# 18                     5                 $881,104             3236
# 19                  3955              $41,282,042             3987
# 20                  3963              $46,018,755             3963
# 21                  3508              $35,535,250             3508
# 22                  3561              $38,527,856             3591
# 23                  3525              $35,028,301             3955
# 24                  3215              $23,817,340             3215
# 25                  3932              $38,155,177             3932
# 26                  4068              $41,039,944             4091
# 27                  3343              $40,406,314             3356
# 28                  2317              $24,074,047             3115
# 29                  3478              $14,869,736             3478
# ..                   ...                      ...              ...
# 456                    2                   $8,370                5
# 457                    1                   $4,962                3
# 458                    1                   $6,330                6
# 459                    1                   $8,244                1
# 460                    1                   $8,101                2
# 461                    7                   $8,015                7
# 462                    1                   $8,534                3
# 463                    1                   $3,489                6
# 464                    1                   $4,809                9
# 465                    2                  $11,320                2
# 466                    2                   $6,886               26
# 467                    7                   $5,609                7
# 468                    3                  $14,569                3
# 469                    1                   $5,995                1
# 470                    3                   $5,064                4
# 471                    1                   $5,538                2
# 472                    2                   $4,905                2
# 473                    1                  $10,295                1
# 474                    5                   $4,090                7
# 475                    1                   $3,495                3
# 476                    3                   $4,875                5
# 477                    1                   $3,072                1
# 478                    1                   $4,300                1
# 479                    0                       $0                2
# 480                    2                   $2,282                2
# 481                    1                   $3,061               10
# 482                    1                   $2,823                1
# 483                    1                   $2,267                1
# 484                    2                   $1,204                2
# 485                    1                   $1,047                1
#
#                                               url_part
# 0                          Rogue-One-A-Star-Wars-Story
# 1                                         Finding-Dory
# 2                            Captain-America-Civil-War
# 3                              Secret-Life-of-Pets-The
# 4                                      Jungle-Book-The
# 5                                             Deadpool
# 6                                             Zootopia
# 7                    Batman-v-Superman-Dawn-of-Justice
# 8                                        Suicide-Squad
# 9                                                 Sing
# 10                                               Moana
# 11             Fantastic-Beasts-and-Where-to-Find-Them
# 12                                      Doctor-Strange
# 13                                      Hidden-Figures
# 14                                        Jason-Bourne
# 15                                    Star-Trek-Beyond
# 16                                    X-Men-Apocalypse
# 17                                              Trolls
# 18                                          La-La-Land
# 19                                     Kung-Fu-Panda-3
# 20                                        Ghostbusters
# 21                                Central-Intelligence
# 22                                Legend-of-Tarzan-The
# 23                                               Sully
# 24                                            Bad-Moms
# 25                               Angry-Birds-Movie-The
# 26                         Independence-Day-Resurgence
# 27             Conjuring-2-The-Enfield-Poltergeist-The
# 28                                             Arrival
# 29                                          Passengers
# ..                                                 ...
# 456                            Sanpo-Suru-Shinryakusha
# 457                                       Tehran-Taboo
# 458                                          A-Ciambra
# 459                         Memorias-del-subdesarrollo
# 460                 24-Frames-Before-and-After-Lumiere
# 461                                      Ridge-Runners
# 462                                            Western
# 463                                            Vazante
# 464                                         Freak-Show
# 465                                         Desolation
# 466                                   Female-Brain-The
# 467                                          Mind-Game
# 468                                            Oh-Lucy
# 469                                 Boy-Downstairs-The
# 470                                            Like-Me
# 471                                             My-Art
# 472              Wedding-Party-2-Destination-Dubai-The
# 473                                        Death-House
# 474                                    Please-Stand-By
# 475                                        Mama-Africa
# 476                                          Cured-The
# 477                        In-the-Land-of-Pomegranates
# 478                                           November
# 479                                Shan-zhong-zhuan-qi
# 480                                           Kangaroo
# 481                              Kickboxer-Retaliation
# 482  American-Socialist-The-Life-and-Times-of-Eugene-…
# 483                                           Souvenir
# 484                                   Cage-Fighter-The
# 485                           West-of-the-Jordan-River
#
# [483 rows x 7 columns]

# %%
i=0
for row in past_data["url_part"]:
    try:
        soup = get_content(row)
        summary = clean_table(soup)
        summary["url_part"] = row
    except AttributeError:
        print("{} seems to be a problem, moving on...".format(row))
        continue
    except KeyError:
        print("Something is missing from the data for {}, moving on...".format(row))
    if i == 0:
        df = past_data.merge(summary, on="url_part")
    else:
        temp = past_data.merge(summary, on="url_part")
        df = pd.concat([df, temp])
    i+=1
df
# Out:
# No luck finding Rogue-One-A-Star-Wars-Story-(2018), will try adding -(2017)
# No luck finding Rogue-One-A-Star-Wars-Story-(2017), will try adding -(2016)
# No luck finding Rogue-One-A-Star-Wars-Story-(2016) either. Will try adding -(2015).
# No luck finding Rogue-One-A-Star-Wars-Story-(2015) either. Will try removing year specification.
# Found and stored data for Rogue-One-A-Star-Wars-Story!
# No luck finding Finding-Dory-(2018), will try adding -(2017)
# No luck finding Finding-Dory-(2017), will try adding -(2016)
# No luck finding Finding-Dory-(2016) either. Will try adding -(2015).
# No luck finding Finding-Dory-(2015) either. Will try removing year specification.
# Found and stored data for Finding-Dory!
# No luck finding Captain-America-Civil-War-(2018), will try adding -(2017)
# No luck finding Captain-America-Civil-War-(2017), will try adding -(2016)
# No luck finding Captain-America-Civil-War-(2016) either. Will try adding -(2015).
# No luck finding Captain-America-Civil-War-(2015) either. Will try removing year specification.
# Found and stored data for Captain-America-Civil-War!
# No luck finding Secret-Life-of-Pets-The-(2018), will try adding -(2017)
# No luck finding Secret-Life-of-Pets-The-(2017), will try adding -(2016)
# No luck finding Secret-Life-of-Pets-The-(2016) either. Will try adding -(2015).
# No luck finding Secret-Life-of-Pets-The-(2015) either. Will try removing year specification.
# Found and stored data for Secret-Life-of-Pets-The!
# No luck finding Jungle-Book-The-(2018), will try adding -(2017)
# No luck finding Jungle-Book-The-(2017), will try adding -(2016)
# Found and stored data for Jungle-Book-The-2016!
# No luck finding Deadpool-(2018), will try adding -(2017)
# No luck finding Deadpool-(2017), will try adding -(2016)
# No luck finding Deadpool-(2016) either. Will try adding -(2015).
# No luck finding Deadpool-(2015) either. Will try removing year specification.
# Found and stored data for Deadpool!
# No luck finding Zootopia-(2018), will try adding -(2017)
# No luck finding Zootopia-(2017), will try adding -(2016)
# No luck finding Zootopia-(2016) either. Will try adding -(2015).
# No luck finding Zootopia-(2015) either. Will try removing year specification.
# Found and stored data for Zootopia!
# No luck finding Batman-v-Superman-Dawn-of-Justice-(2018), will try adding -(2017)
# No luck finding Batman-v-Superman-Dawn-of-Justice-(2017), will try adding -(2016)
# No luck finding Batman-v-Superman-Dawn-of-Justice-(2016) either. Will try adding -(2015).
# No luck finding Batman-v-Superman-Dawn-of-Justice-(2015) either. Will try removing year specification.
# Found and stored data for Batman-v-Superman-Dawn-of-Justice!
# No luck finding Suicide-Squad-(2018), will try adding -(2017)
# No luck finding Suicide-Squad-(2017), will try adding -(2016)
# No luck finding Suicide-Squad-(2016) either. Will try adding -(2015).
# No luck finding Suicide-Squad-(2015) either. Will try removing year specification.
# Found and stored data for Suicide-Squad!
# No luck finding Sing-(2018), will try adding -(2017)
# No luck finding Sing-(2017), will try adding -(2016)
# Found and stored data for Sing-2016!
# No luck finding Moana-(2018), will try adding -(2017)
# No luck finding Moana-(2017), will try adding -(2016)
# Found and stored data for Moana-2016!
# No luck finding Fantastic-Beasts-and-Where-to-Find-Them-(2018), will try adding -(2017)
# No luck finding Fantastic-Beasts-and-Where-to-Find-Them-(2017), will try adding -(2016)
# No luck finding Fantastic-Beasts-and-Where-to-Find-Them-(2016) either. Will try adding -(2015).
# No luck finding Fantastic-Beasts-and-Where-to-Find-Them-(2015) either. Will try removing year specification.
# Found and stored data for Fantastic-Beasts-and-Where-to-Find-Them!
# No luck finding Doctor-Strange-(2018), will try adding -(2017)
# No luck finding Doctor-Strange-(2017), will try adding -(2016)
# Found and stored data for Doctor-Strange-2016!
# No luck finding Hidden-Figures-(2018), will try adding -(2017)
# No luck finding Hidden-Figures-(2017), will try adding -(2016)
# No luck finding Hidden-Figures-(2016) either. Will try adding -(2015).
# No luck finding Hidden-Figures-(2015) either. Will try removing year specification.
# Found and stored data for Hidden-Figures!
# No luck finding Jason-Bourne-(2018), will try adding -(2017)
# No luck finding Jason-Bourne-(2017), will try adding -(2016)
# No luck finding Jason-Bourne-(2016) either. Will try adding -(2015).
# No luck finding Jason-Bourne-(2015) either. Will try removing year specification.
# Found and stored data for Jason-Bourne!
# No luck finding Star-Trek-Beyond-(2018), will try adding -(2017)
# No luck finding Star-Trek-Beyond-(2017), will try adding -(2016)
# No luck finding Star-Trek-Beyond-(2016) either. Will try adding -(2015).
# No luck finding Star-Trek-Beyond-(2015) either. Will try removing year specification.
# Found and stored data for Star-Trek-Beyond!
# No luck finding X-Men-Apocalypse-(2018), will try adding -(2017)
# No luck finding X-Men-Apocalypse-(2017), will try adding -(2016)
# No luck finding X-Men-Apocalypse-(2016) either. Will try adding -(2015).
# No luck finding X-Men-Apocalypse-(2015) either. Will try removing year specification.
# Found and stored data for X-Men-Apocalypse!
# No luck finding Trolls-(2018), will try adding -(2017)
# No luck finding Trolls-(2017), will try adding -(2016)
# No luck finding Trolls-(2016) either. Will try adding -(2015).
# No luck finding Trolls-(2015) either. Will try removing year specification.
# Found and stored data for Trolls!
# No luck finding La-La-Land-(2018), will try adding -(2017)
# No luck finding La-La-Land-(2017), will try adding -(2016)
# No luck finding La-La-Land-(2016) either. Will try adding -(2015).
# No luck finding La-La-Land-(2015) either. Will try removing year specification.
# Found and stored data for La-La-Land!
# No luck finding Kung-Fu-Panda-3-(2018), will try adding -(2017)
# No luck finding Kung-Fu-Panda-3-(2017), will try adding -(2016)
# No luck finding Kung-Fu-Panda-3-(2016) either. Will try adding -(2015).
# No luck finding Kung-Fu-Panda-3-(2015) either. Will try removing year specification.
# Found and stored data for Kung-Fu-Panda-3!
# No luck finding Ghostbusters-(2018), will try adding -(2017)
# No luck finding Ghostbusters-(2017), will try adding -(2016)
# Found and stored data for Ghostbusters-2016!
# No luck finding Central-Intelligence-(2018), will try adding -(2017)
# No luck finding Central-Intelligence-(2017), will try adding -(2016)
# No luck finding Central-Intelligence-(2016) either. Will try adding -(2015).
# No luck finding Central-Intelligence-(2015) either. Will try removing year specification.
# Found and stored data for Central-Intelligence!
# No luck finding Legend-of-Tarzan-The-(2018), will try adding -(2017)
# No luck finding Legend-of-Tarzan-The-(2017), will try adding -(2016)
# No luck finding Legend-of-Tarzan-The-(2016) either. Will try adding -(2015).
# No luck finding Legend-of-Tarzan-The-(2015) either. Will try removing year specification.
# Found and stored data for Legend-of-Tarzan-The!
# No luck finding Sully-(2018), will try adding -(2017)
# No luck finding Sully-(2017), will try adding -(2016)
# No luck finding Sully-(2016) either. Will try adding -(2015).
# No luck finding Sully-(2015) either. Will try removing year specification.
# Found and stored data for Sully!
# No luck finding Bad-Moms-(2018), will try adding -(2017)
# No luck finding Bad-Moms-(2017), will try adding -(2016)
# No luck finding Bad-Moms-(2016) either. Will try adding -(2015).
# No luck finding Bad-Moms-(2015) either. Will try removing year specification.
# Found and stored data for Bad-Moms!
# No luck finding Angry-Birds-Movie-The-(2018), will try adding -(2017)
# No luck finding Angry-Birds-Movie-The-(2017), will try adding -(2016)
# No luck finding Angry-Birds-Movie-The-(2016) either. Will try adding -(2015).
# No luck finding Angry-Birds-Movie-The-(2015) either. Will try removing year specification.
# Found and stored data for Angry-Birds-Movie-The!
# No luck finding Independence-Day-Resurgence-(2018), will try adding -(2017)
# No luck finding Independence-Day-Resurgence-(2017), will try adding -(2016)
# No luck finding Independence-Day-Resurgence-(2016) either. Will try adding -(2015).
# No luck finding Independence-Day-Resurgence-(2015) either. Will try removing year specification.
# Found and stored data for Independence-Day-Resurgence!
# No luck finding Conjuring-2-The-Enfield-Poltergeist-The-(2018), will try adding -(2017)
# No luck finding Conjuring-2-The-Enfield-Poltergeist-The-(2017), will try adding -(2016)
# No luck finding Conjuring-2-The-Enfield-Poltergeist-The-(2016) either. Will try adding -(2015).
# No luck finding Conjuring-2-The-Enfield-Poltergeist-The-(2015) either. Will try removing year specification.
# Found and stored data for Conjuring-2-The-Enfield-Poltergeist-The!
# No luck finding Arrival-(2018), will try adding -(2017)
# No luck finding Arrival-(2017), will try adding -(2016)
# Found and stored data for Arrival-2016!
# No luck finding Passengers-(2018), will try adding -(2017)
# Found and stored data for Passengers-2017!
# No luck finding Sausage-Party-(2018), will try adding -(2017)
# No luck finding Sausage-Party-(2017), will try adding -(2016)
# No luck finding Sausage-Party-(2016) either. Will try adding -(2015).
# No luck finding Sausage-Party-(2015) either. Will try removing year specification.
# Found and stored data for Sausage-Party!
# No luck finding Magnificent-Seven-The-(2018), will try adding -(2017)
# No luck finding Magnificent-Seven-The-(2017), will try adding -(2016)
# Found and stored data for Magnificent-Seven-The-2016!
# No luck finding Ride-Along-2-(2018), will try adding -(2017)
# No luck finding Ride-Along-2-(2017), will try adding -(2016)
# No luck finding Ride-Along-2-(2016) either. Will try adding -(2015).
# No luck finding Ride-Along-2-(2015) either. Will try removing year specification.
# Found and stored data for Ride-Along-2!
# No luck finding Dont-Breathe-(2018), will try adding -(2017)
# No luck finding Dont-Breathe-(2017), will try adding -(2016)
# No luck finding Dont-Breathe-(2016) either. Will try adding -(2015).
# No luck finding Dont-Breathe-(2015) either. Will try removing year specification.
# Found and stored data for Dont-Breathe!
# No luck finding Miss-Peregrines-Home-for-Peculiar-Children-(2018), will try adding -(2017)
# No luck finding Miss-Peregrines-Home-for-Peculiar-Children-(2017), will try adding -(2016)
# No luck finding Miss-Peregrines-Home-for-Peculiar-Children-(2016) either. Will try adding -(2015).
# No luck finding Miss-Peregrines-Home-for-Peculiar-Children-(2015) either. Will try removing year specification.
# Found and stored data for Miss-Peregrines-Home-for-Peculiar-Children!
# No luck finding Accountant-The-(2018), will try adding -(2017)
# No luck finding Accountant-The-(2017), will try adding -(2016)
# No luck finding Accountant-The-(2016) either. Will try adding -(2015).
# No luck finding Accountant-The-(2015) either. Will try removing year specification.
# Found and stored data for Accountant-The!
# No luck finding Teenage-Mutant-Ninja-Turtles-Out-of-the-Shadows-(2018), will try adding -(2017)
# No luck finding Teenage-Mutant-Ninja-Turtles-Out-of-the-Shadows-(2017), will try adding -(2016)
# No luck finding Teenage-Mutant-Ninja-Turtles-Out-of-the-Shadows-(2016) either. Will try adding -(2015).
# No luck finding Teenage-Mutant-Ninja-Turtles-Out-of-the-Shadows-(2015) either. Will try removing year specification.
# Found and stored data for Teenage-Mutant-Ninja-Turtles-Out-of-the-Shadows!
# No luck finding Purge-Election-Year-The-(2018), will try adding -(2017)
# No luck finding Purge-Election-Year-The-(2017), will try adding -(2016)
# No luck finding Purge-Election-Year-The-(2016) either. Will try adding -(2015).
# No luck finding Purge-Election-Year-The-(2015) either. Will try removing year specification.
# "Looks like Purge-Election-Year-The doesn't exist on the-numbers.com. Try a google search?"
# Purge-Election-Year-The seems to be a problem, moving on...
# No luck finding Alice-Through-the-Looking-Glass-(2018), will try adding -(2017)
# No luck finding Alice-Through-the-Looking-Glass-(2017), will try adding -(2016)
# No luck finding Alice-Through-the-Looking-Glass-(2016) either. Will try adding -(2015).
# No luck finding Alice-Through-the-Looking-Glass-(2015) either. Will try removing year specification.
# Found and stored data for Alice-Through-the-Looking-Glass!
# No luck finding Petes-Dragon-(2018), will try adding -(2017)
# No luck finding Petes-Dragon-(2017), will try adding -(2016)
# Found and stored data for Petes-Dragon-2016!
# No luck finding Girl-on-the-Train-The-(2018), will try adding -(2017)
# No luck finding Girl-on-the-Train-The-(2017), will try adding -(2016)
# Found and stored data for Girl-on-the-Train-The-2016!
# No luck finding Tyler-Perrys-Boo-A-Madea-Halloween-(2018), will try adding -(2017)
# No luck finding Tyler-Perrys-Boo-A-Madea-Halloween-(2017), will try adding -(2016)
# No luck finding Tyler-Perrys-Boo-A-Madea-Halloween-(2016) either. Will try adding -(2015).
# No luck finding Tyler-Perrys-Boo-A-Madea-Halloween-(2015) either. Will try removing year specification.
# Found and stored data for Tyler-Perrys-Boo-A-Madea-Halloween!
# No luck finding Storks-(2018), will try adding -(2017)
# No luck finding Storks-(2017), will try adding -(2016)
# No luck finding Storks-(2016) either. Will try adding -(2015).
# No luck finding Storks-(2015) either. Will try removing year specification.
# Found and stored data for Storks!
# No luck finding 10-Cloverfield-Lane-(2018), will try adding -(2017)
# No luck finding 10-Cloverfield-Lane-(2017), will try adding -(2016)
# No luck finding 10-Cloverfield-Lane-(2016) either. Will try adding -(2015).
# No luck finding 10-Cloverfield-Lane-(2015) either. Will try removing year specification.
# Found and stored data for 10-Cloverfield-Lane!
# No luck finding Lights-Out-(2018), will try adding -(2017)
# No luck finding Lights-Out-(2017), will try adding -(2016)
# Found and stored data for Lights-Out-2016!
# No luck finding Hacksaw-Ridge-(2018), will try adding -(2017)
# No luck finding Hacksaw-Ridge-(2017), will try adding -(2016)
# No luck finding Hacksaw-Ridge-(2016) either. Will try adding -(2015).
# No luck finding Hacksaw-Ridge-(2015) either. Will try removing year specification.
# Found and stored data for Hacksaw-Ridge!
# No luck finding Divergent-Series-Allegiant-The-(2018), will try adding -(2017)
# No luck finding Divergent-Series-Allegiant-The-(2017), will try adding -(2016)
# No luck finding Divergent-Series-Allegiant-The-(2016) either. Will try adding -(2015).
# No luck finding Divergent-Series-Allegiant-The-(2015) either. Will try removing year specification.
# Found and stored data for Divergent-Series-Allegiant-The!
# No luck finding Now-You-See-Me-2-(2018), will try adding -(2017)
# No luck finding Now-You-See-Me-2-(2017), will try adding -(2016)
# No luck finding Now-You-See-Me-2-(2016) either. Will try adding -(2015).
# No luck finding Now-You-See-Me-2-(2015) either. Will try removing year specification.
# Found and stored data for Now-You-See-Me-2!
# No luck finding Ice-Age-Collision-Course-(2018), will try adding -(2017)
# No luck finding Ice-Age-Collision-Course-(2017), will try adding -(2016)
# No luck finding Ice-Age-Collision-Course-(2016) either. Will try adding -(2015).
# No luck finding Ice-Age-Collision-Course-(2015) either. Will try removing year specification.
# Found and stored data for Ice-Age-Collision-Course!
# No luck finding Boss-The-(2018), will try adding -(2017)
# No luck finding Boss-The-(2017), will try adding -(2016)
# No luck finding Boss-The-(2016) either. Will try adding -(2015).
# No luck finding Boss-The-(2015) either. Will try removing year specification.
# Found and stored data for Boss-The!
# No luck finding London-Has-Fallen-(2018), will try adding -(2017)
# No luck finding London-Has-Fallen-(2017), will try adding -(2016)
# No luck finding London-Has-Fallen-(2016) either. Will try adding -(2015).
# No luck finding London-Has-Fallen-(2015) either. Will try removing year specification.
# Found and stored data for London-Has-Fallen!
# No luck finding Miracles-from-Heaven-(2018), will try adding -(2017)
# No luck finding Miracles-from-Heaven-(2017), will try adding -(2016)
# No luck finding Miracles-from-Heaven-(2016) either. Will try adding -(2015).
# No luck finding Miracles-from-Heaven-(2015) either. Will try removing year specification.
# Found and stored data for Miracles-from-Heaven!
# No luck finding Deepwater-Horizon-(2018), will try adding -(2017)
# No luck finding Deepwater-Horizon-(2017), will try adding -(2016)
# No luck finding Deepwater-Horizon-(2016) either. Will try adding -(2015).
# No luck finding Deepwater-Horizon-(2015) either. Will try removing year specification.
# Found and stored data for Deepwater-Horizon!
# Found and stored data for Why-Him?-2018!
# No luck finding My-Big-Fat-Greek-Wedding-2-(2018), will try adding -(2017)
# No luck finding My-Big-Fat-Greek-Wedding-2-(2017), will try adding -(2016)
# No luck finding My-Big-Fat-Greek-Wedding-2-(2016) either. Will try adding -(2015).
# No luck finding My-Big-Fat-Greek-Wedding-2-(2015) either. Will try removing year specification.
# Found and stored data for My-Big-Fat-Greek-Wedding-2!
# No luck finding Jack-Reacher-Never-Go-Back-(2018), will try adding -(2017)
# No luck finding Jack-Reacher-Never-Go-Back-(2017), will try adding -(2016)
# No luck finding Jack-Reacher-Never-Go-Back-(2016) either. Will try adding -(2015).
# No luck finding Jack-Reacher-Never-Go-Back-(2015) either. Will try removing year specification.
# Found and stored data for Jack-Reacher-Never-Go-Back!
# No luck finding Fences-(2018), will try adding -(2017)
# No luck finding Fences-(2017), will try adding -(2016)
# No luck finding Fences-(2016) either. Will try adding -(2015).
# No luck finding Fences-(2015) either. Will try removing year specification.
# Found and stored data for Fences!
# No luck finding Me-Before-You-(2018), will try adding -(2017)
# No luck finding Me-Before-You-(2017), will try adding -(2016)
# No luck finding Me-Before-You-(2016) either. Will try adding -(2015).
# No luck finding Me-Before-You-(2015) either. Will try removing year specification.
# Found and stored data for Me-Before-You!
# No luck finding BFG-The-(2018), will try adding -(2017)
# No luck finding BFG-The-(2017), will try adding -(2016)
# Found and stored data for BFG-The-2016!
# No luck finding Neighbors-2-Sorority-Rising-(2018), will try adding -(2017)
# No luck finding Neighbors-2-Sorority-Rising-(2017), will try adding -(2016)
# No luck finding Neighbors-2-Sorority-Rising-(2016) either. Will try adding -(2015).
# No luck finding Neighbors-2-Sorority-Rising-(2015) either. Will try removing year specification.
# Found and stored data for Neighbors-2-Sorority-Rising!
# No luck finding Shallows-The-(2018), will try adding -(2017)
# No luck finding Shallows-The-(2017), will try adding -(2016)
# No luck finding Shallows-The-(2016) either. Will try adding -(2015).
# No luck finding Shallows-The-(2015) either. Will try removing year specification.
# Found and stored data for Shallows-The!
# No luck finding Office-Christmas-Party-(2018), will try adding -(2017)
# No luck finding Office-Christmas-Party-(2017), will try adding -(2016)
# No luck finding Office-Christmas-Party-(2016) either. Will try adding -(2015).
# No luck finding Office-Christmas-Party-(2015) either. Will try removing year specification.
# Found and stored data for Office-Christmas-Party!
# No luck finding Assassins-Creed-(2018), will try adding -(2017)
# No luck finding Assassins-Creed-(2017), will try adding -(2016)
# No luck finding Assassins-Creed-(2016) either. Will try adding -(2015).
# No luck finding Assassins-Creed-(2015) either. Will try removing year specification.
# Found and stored data for Assassins-Creed!
# No luck finding Barbershop-The-Next-Cut-(2018), will try adding -(2017)
# No luck finding Barbershop-The-Next-Cut-(2017), will try adding -(2016)
# No luck finding Barbershop-The-Next-Cut-(2016) either. Will try adding -(2015).
# No luck finding Barbershop-The-Next-Cut-(2015) either. Will try removing year specification.
# Found and stored data for Barbershop-The-Next-Cut!
# No luck finding 13-Hours-The-Secret-Soldiers-of-Benghazi-(2018), will try adding -(2017)
# No luck finding 13-Hours-The-Secret-Soldiers-of-Benghazi-(2017), will try adding -(2016)
# No luck finding 13-Hours-The-Secret-Soldiers-of-Benghazi-(2016) either. Will try adding -(2015).
# No luck finding 13-Hours-The-Secret-Soldiers-of-Benghazi-(2015) either. Will try removing year specification.
# Found and stored data for 13-Hours-The-Secret-Soldiers-of-Benghazi!
# No luck finding Lion-(2018), will try adding -(2017)
# No luck finding Lion-(2017), will try adding -(2016)
# No luck finding Lion-(2016) either. Will try adding -(2015).
# No luck finding Lion-(2015) either. Will try removing year specification.
# Found and stored data for Lion!
# No luck finding Kubo-and-the-Two-Strings-(2018), will try adding -(2017)
# No luck finding Kubo-and-the-Two-Strings-(2017), will try adding -(2016)
# No luck finding Kubo-and-the-Two-Strings-(2016) either. Will try adding -(2015).
# No luck finding Kubo-and-the-Two-Strings-(2015) either. Will try removing year specification.
# Found and stored data for Kubo-and-the-Two-Strings!
# No luck finding Huntsman-Winters-War-The-(2018), will try adding -(2017)
# No luck finding Huntsman-Winters-War-The-(2017), will try adding -(2016)
# No luck finding Huntsman-Winters-War-The-(2016) either. Will try adding -(2015).
# No luck finding Huntsman-Winters-War-The-(2015) either. Will try removing year specification.
# Found and stored data for Huntsman-Winters-War-The!
# No luck finding Manchester-by-the-Sea-(2018), will try adding -(2017)
# No luck finding Manchester-by-the-Sea-(2017), will try adding -(2016)
# No luck finding Manchester-by-the-Sea-(2016) either. Will try adding -(2015).
# No luck finding Manchester-by-the-Sea-(2015) either. Will try removing year specification.
# Found and stored data for Manchester-by-the-Sea!
# No luck finding Warcraft-(2018), will try adding -(2017)
# No luck finding Warcraft-(2017), will try adding -(2016)
# No luck finding Warcraft-(2016) either. Will try adding -(2015).
# No luck finding Warcraft-(2015) either. Will try removing year specification.
# Found and stored data for Warcraft!
# No luck finding How-to-be-Single-(2018), will try adding -(2017)
# No luck finding How-to-be-Single-(2017), will try adding -(2016)
# No luck finding How-to-be-Single-(2016) either. Will try adding -(2015).
# No luck finding How-to-be-Single-(2015) either. Will try removing year specification.
# Found and stored data for How-to-be-Single!
# No luck finding Mike-and-Dave-Need-Wedding-Dates-(2018), will try adding -(2017)
# No luck finding Mike-and-Dave-Need-Wedding-Dates-(2017), will try adding -(2016)
# No luck finding Mike-and-Dave-Need-Wedding-Dates-(2016) either. Will try adding -(2015).
# No luck finding Mike-and-Dave-Need-Wedding-Dates-(2015) either. Will try removing year specification.
# Found and stored data for Mike-and-Dave-Need-Wedding-Dates!
# No luck finding War-Dogs-(2018), will try adding -(2017)
# No luck finding War-Dogs-(2017), will try adding -(2016)
# No luck finding War-Dogs-(2016) either. Will try adding -(2015).
# No luck finding War-Dogs-(2015) either. Will try removing year specification.
# Found and stored data for War-Dogs!
# No luck finding Almost-Christmas-(2018), will try adding -(2017)
# No luck finding Almost-Christmas-(2017), will try adding -(2016)
# No luck finding Almost-Christmas-(2016) either. Will try adding -(2015).
# No luck finding Almost-Christmas-(2015) either. Will try removing year specification.
# Found and stored data for Almost-Christmas!
# No luck finding Money-Monster-(2018), will try adding -(2017)
# No luck finding Money-Monster-(2017), will try adding -(2016)
# No luck finding Money-Monster-(2016) either. Will try adding -(2015).
# No luck finding Money-Monster-(2015) either. Will try removing year specification.
# Found and stored data for Money-Monster!
# No luck finding Allied-(2018), will try adding -(2017)
# No luck finding Allied-(2017), will try adding -(2016)
# No luck finding Allied-(2016) either. Will try adding -(2015).
# No luck finding Allied-(2015) either. Will try removing year specification.
# Found and stored data for Allied!
# No luck finding Nerve-(2018), will try adding -(2017)
# No luck finding Nerve-(2017), will try adding -(2016)
# No luck finding Nerve-(2016) either. Will try adding -(2015).
# No luck finding Nerve-(2015) either. Will try removing year specification.
# Found and stored data for Nerve!
# No luck finding Risen-(2018), will try adding -(2017)
# No luck finding Risen-(2017), will try adding -(2016)
# No luck finding Risen-(2016) either. Will try adding -(2015).
# No luck finding Risen-(2015) either. Will try removing year specification.
# Found and stored data for Risen!
# No luck finding Nice-Guys-The-(2018), will try adding -(2017)
# No luck finding Nice-Guys-The-(2017), will try adding -(2016)
# No luck finding Nice-Guys-The-(2016) either. Will try adding -(2015).
# No luck finding Nice-Guys-The-(2015) either. Will try removing year specification.
# Found and stored data for Nice-Guys-The!
# No luck finding Boy-The-(2018), will try adding -(2017)
# No luck finding Boy-The-(2017), will try adding -(2016)
# Found and stored data for Boy-The-2016!
# No luck finding Dirty-Grandpa-(2018), will try adding -(2017)
# No luck finding Dirty-Grandpa-(2017), will try adding -(2016)
# No luck finding Dirty-Grandpa-(2016) either. Will try adding -(2015).
# No luck finding Dirty-Grandpa-(2015) either. Will try removing year specification.
# Found and stored data for Dirty-Grandpa!
# No luck finding Ouija-Origin-of-Evil-(2018), will try adding -(2017)
# No luck finding Ouija-Origin-of-Evil-(2017), will try adding -(2016)
# No luck finding Ouija-Origin-of-Evil-(2016) either. Will try adding -(2015).
# No luck finding Ouija-Origin-of-Evil-(2015) either. Will try removing year specification.
# Found and stored data for Ouija-Origin-of-Evil!
# No luck finding 5th-Wave-The-(2018), will try adding -(2017)
# No luck finding 5th-Wave-The-(2017), will try adding -(2016)
# No luck finding 5th-Wave-The-(2016) either. Will try adding -(2015).
# No luck finding 5th-Wave-The-(2015) either. Will try removing year specification.
# Found and stored data for 5th-Wave-The!
# No luck finding Inferno-(2018), will try adding -(2017)
# No luck finding Inferno-(2017), will try adding -(2016)
# No luck finding Inferno-(2016) either. Will try adding -(2015).
# No luck finding Inferno-(2015) either. Will try removing year specification.
# Found and stored data for Inferno!
# No luck finding Mothers-Day-(2018), will try adding -(2017)
# No luck finding Mothers-Day-(2017), will try adding -(2016)
# Found and stored data for Mothers-Day-2016!
# No luck finding Patriots-Day-(2018), will try adding -(2017)
# No luck finding Patriots-Day-(2017), will try adding -(2016)
# No luck finding Patriots-Day-(2016) either. Will try adding -(2015).
# No luck finding Patriots-Day-(2015) either. Will try removing year specification.
# Found and stored data for Patriots-Day!
# No luck finding Gods-of-Egypt-(2018), will try adding -(2017)
# No luck finding Gods-of-Egypt-(2017), will try adding -(2016)
# No luck finding Gods-of-Egypt-(2016) either. Will try adding -(2015).
# No luck finding Gods-of-Egypt-(2015) either. Will try removing year specification.
# Found and stored data for Gods-of-Egypt!
# No luck finding Collateral-Beauty-(2018), will try adding -(2017)
# No luck finding Collateral-Beauty-(2017), will try adding -(2016)
# No luck finding Collateral-Beauty-(2016) either. Will try adding -(2015).
# No luck finding Collateral-Beauty-(2015) either. Will try removing year specification.
# Found and stored data for Collateral-Beauty!
# No luck finding Hail-Caesar-(2018), will try adding -(2017)
# No luck finding Hail-Caesar-(2017), will try adding -(2016)
# Found and stored data for Hail-Caesar-2016!
# No luck finding When-the-Bough-Breaks-(2018), will try adding -(2017)
# No luck finding When-the-Bough-Breaks-(2017), will try adding -(2016)
# No luck finding When-the-Bough-Breaks-(2016) either. Will try adding -(2015).
# No luck finding When-the-Bough-Breaks-(2015) either. Will try removing year specification.
# Found and stored data for When-the-Bough-Breaks!
# No luck finding Zoolander-2-(2018), will try adding -(2017)
# No luck finding Zoolander-2-(2017), will try adding -(2016)
# No luck finding Zoolander-2-(2016) either. Will try adding -(2015).
# No luck finding Zoolander-2-(2015) either. Will try removing year specification.
# Found and stored data for Zoolander-2!
# No luck finding Moonlight-(2018), will try adding -(2017)
# No luck finding Moonlight-(2017), will try adding -(2016)
# No luck finding Moonlight-(2016) either. Will try adding -(2015).
# Found and stored data for Moonlight!
# No luck finding Finest-Hours-The-(2018), will try adding -(2017)
# No luck finding Finest-Hours-The-(2017), will try adding -(2016)
# No luck finding Finest-Hours-The-(2016) either. Will try adding -(2015).
# No luck finding Finest-Hours-The-(2015) either. Will try removing year specification.
# Found and stored data for Finest-Hours-The!
# No luck finding Florence-Foster-Jenkins-(2018), will try adding -(2017)
# No luck finding Florence-Foster-Jenkins-(2017), will try adding -(2016)
# No luck finding Florence-Foster-Jenkins-(2016) either. Will try adding -(2015).
# No luck finding Florence-Foster-Jenkins-(2015) either. Will try removing year specification.
# Found and stored data for Florence-Foster-Jenkins!
# No luck finding Hell-or-High-Water-(2018), will try adding -(2017)
# No luck finding Hell-or-High-Water-(2017), will try adding -(2016)
# No luck finding Hell-or-High-Water-(2016) either. Will try adding -(2015).
# No luck finding Hell-or-High-Water-(2015) either. Will try removing year specification.
# Found and stored data for Hell-or-High-Water!
# No luck finding Forest-The-(2018), will try adding -(2017)
# No luck finding Forest-The-(2017), will try adding -(2016)
# No luck finding Forest-The-(2016) either. Will try adding -(2015).
# No luck finding Forest-The-(2015) either. Will try removing year specification.
# Found and stored data for Forest-The!
# No luck finding Ben-Hur-(2018), will try adding -(2017)
# No luck finding Ben-Hur-(2017), will try adding -(2016)
# Found and stored data for Ben-Hur-2016!
# No luck finding Witch-The-(2018), will try adding -(2017)
# No luck finding Witch-The-(2017), will try adding -(2016)
# No luck finding Witch-The-(2016) either. Will try adding -(2015).
# No luck finding Witch-The-(2015) either. Will try removing year specification.
# Found and stored data for Witch-The!
# No luck finding Bridget-Joness-Baby-(2018), will try adding -(2017)
# No luck finding Bridget-Joness-Baby-(2017), will try adding -(2016)
# No luck finding Bridget-Joness-Baby-(2016) either. Will try adding -(2015).
# No luck finding Bridget-Joness-Baby-(2015) either. Will try removing year specification.
# Found and stored data for Bridget-Joness-Baby!
# Found and stored data for Kevin-Hart-What-Now?-2018!
# No luck finding Whiskey-Tango-Foxtrot-(2018), will try adding -(2017)
# No luck finding Whiskey-Tango-Foxtrot-(2017), will try adding -(2016)
# No luck finding Whiskey-Tango-Foxtrot-(2016) either. Will try adding -(2015).
# No luck finding Whiskey-Tango-Foxtrot-(2015) either. Will try removing year specification.
# Found and stored data for Whiskey-Tango-Foxtrot!
# No luck finding Snowden-(2018), will try adding -(2017)
# No luck finding Snowden-(2017), will try adding -(2016)
# No luck finding Snowden-(2016) either. Will try adding -(2015).
# No luck finding Snowden-(2015) either. Will try removing year specification.
# Found and stored data for Snowden!
# No luck finding Mechanic-Resurrection-(2018), will try adding -(2017)
# No luck finding Mechanic-Resurrection-(2017), will try adding -(2016)
# No luck finding Mechanic-Resurrection-(2016) either. Will try adding -(2015).
# No luck finding Mechanic-Resurrection-(2015) either. Will try removing year specification.
# Found and stored data for Mechanic-Resurrection!
# No luck finding Free-State-of-Jones-(2018), will try adding -(2017)
# No luck finding Free-State-of-Jones-(2017), will try adding -(2016)
# No luck finding Free-State-of-Jones-(2016) either. Will try adding -(2015).
# No luck finding Free-State-of-Jones-(2015) either. Will try removing year specification.
# Found and stored data for Free-State-of-Jones!
# No luck finding Blair-Witch-(2018), will try adding -(2017)
# No luck finding Blair-Witch-(2017), will try adding -(2016)
# Found and stored data for Blair-Witch-2016!
# No luck finding Gods-Not-Dead-2-(2018), will try adding -(2017)
# No luck finding Gods-Not-Dead-2-(2017), will try adding -(2016)
# No luck finding Gods-Not-Dead-2-(2016) either. Will try adding -(2015).
# No luck finding Gods-Not-Dead-2-(2015) either. Will try removing year specification.
# Found and stored data for Gods-Not-Dead-2!
# No luck finding Keanu-(2018), will try adding -(2017)
# No luck finding Keanu-(2017), will try adding -(2016)
# No luck finding Keanu-(2016) either. Will try adding -(2015).
# No luck finding Keanu-(2015) either. Will try removing year specification.
# Found and stored data for Keanu!
# No luck finding Middle-School-The-Worst-Years-of-My-Life-(2018), will try adding -(2017)
# No luck finding Middle-School-The-Worst-Years-of-My-Life-(2017), will try adding -(2016)
# No luck finding Middle-School-The-Worst-Years-of-My-Life-(2016) either. Will try adding -(2015).
# No luck finding Middle-School-The-Worst-Years-of-My-Life-(2015) either. Will try removing year specification.
# Found and stored data for Middle-School-The-Worst-Years-of-My-Life!
# No luck finding Nine-Lives-(2018), will try adding -(2017)
# No luck finding Nine-Lives-(2017), will try adding -(2016)
# Found and stored data for Nine-Lives-2016!
# No luck finding Race-(2018), will try adding -(2017)
# No luck finding Race-(2017), will try adding -(2016)
# Found and stored data for Race-2016!
# No luck finding Choice-The-(2018), will try adding -(2017)
# No luck finding Choice-The-(2017), will try adding -(2016)
# No luck finding Choice-The-(2016) either. Will try adding -(2015).
# Found and stored data for Choice-The!
# No luck finding Eye-in-the-Sky-(2018), will try adding -(2017)
# No luck finding Eye-in-the-Sky-(2017), will try adding -(2016)
# No luck finding Eye-in-the-Sky-(2016) either. Will try adding -(2015).
# No luck finding Eye-in-the-Sky-(2015) either. Will try removing year specification.
# Found and stored data for Eye-in-the-Sky!
# No luck finding Bad-Santa-2-(2018), will try adding -(2017)
# No luck finding Bad-Santa-2-(2017), will try adding -(2016)
# No luck finding Bad-Santa-2-(2016) either. Will try adding -(2015).
# No luck finding Bad-Santa-2-(2015) either. Will try removing year specification.
# Found and stored data for Bad-Santa-2!
# No luck finding Masterminds-(2018), will try adding -(2017)
# No luck finding Masterminds-(2017), will try adding -(2016)
# No luck finding Masterminds-(2016) either. Will try adding -(2015).
# Found and stored data for Masterminds!
# No luck finding Norm-of-the-North-(2018), will try adding -(2017)
# No luck finding Norm-of-the-North-(2017), will try adding -(2016)
# No luck finding Norm-of-the-North-(2016) either. Will try adding -(2015).
# No luck finding Norm-of-the-North-(2015) either. Will try removing year specification.
# Found and stored data for Norm-of-the-North!
# No luck finding Birth-of-a-Nation-The-(2018), will try adding -(2017)
# No luck finding Birth-of-a-Nation-The-(2017), will try adding -(2016)
# Found and stored data for Birth-of-a-Nation-The-2016!
# No luck finding Eddie-the-Eagle-(2018), will try adding -(2017)
# No luck finding Eddie-the-Eagle-(2017), will try adding -(2016)
# No luck finding Eddie-the-Eagle-(2016) either. Will try adding -(2015).
# No luck finding Eddie-the-Eagle-(2015) either. Will try removing year specification.
# Found and stored data for Eddie-the-Eagle!
# No luck finding Infiltrator-The-(2018), will try adding -(2017)
# No luck finding Infiltrator-The-(2017), will try adding -(2016)
# No luck finding Infiltrator-The-(2016) either. Will try adding -(2015).
# No luck finding Infiltrator-The-(2015) either. Will try removing year specification.
# Found and stored data for Infiltrator-The!
# No luck finding Keeping-Up-with-the-Joneses-(2018), will try adding -(2017)
# No luck finding Keeping-Up-with-the-Joneses-(2017), will try adding -(2016)
# No luck finding Keeping-Up-with-the-Joneses-(2016) either. Will try adding -(2015).
# No luck finding Keeping-Up-with-the-Joneses-(2015) either. Will try removing year specification.
# Found and stored data for Keeping-Up-with-the-Joneses!
# No luck finding Criminal-(2018), will try adding -(2017)
# No luck finding Criminal-(2017), will try adding -(2016)
# No luck finding Criminal-(2016) either. Will try adding -(2015).
# Found and stored data for Criminal!
# No luck finding Hello-My-Name-is-Doris-(2018), will try adding -(2017)
# No luck finding Hello-My-Name-is-Doris-(2017), will try adding -(2016)
# No luck finding Hello-My-Name-is-Doris-(2016) either. Will try adding -(2015).
# No luck finding Hello-My-Name-is-Doris-(2015) either. Will try removing year specification.
# Found and stored data for Hello-My-Name-is-Doris!
# No luck finding Edge-of-Seventeen-The-(2018), will try adding -(2017)
# No luck finding Edge-of-Seventeen-The-(2017), will try adding -(2016)
# Found and stored data for Edge-of-Seventeen-The-2016!
# No luck finding Love-and-Friendship-(2018), will try adding -(2017)
# No luck finding Love-and-Friendship-(2017), will try adding -(2016)
# No luck finding Love-and-Friendship-(2016) either. Will try adding -(2015).
# No luck finding Love-and-Friendship-(2015) either. Will try removing year specification.
# Found and stored data for Love-and-Friendship!
# No luck finding Jackie-(2018), will try adding -(2017)
# No luck finding Jackie-(2017), will try adding -(2016)
# Found and stored data for Jackie-2016!
# No luck finding Hillarys-America-The-Secret-History-of-the-…-(2018), will try adding -(2017)
# No luck finding Hillarys-America-The-Secret-History-of-the-…-(2017), will try adding -(2016)
# No luck finding Hillarys-America-The-Secret-History-of-the-…-(2016) either. Will try adding -(2015).
# No luck finding Hillarys-America-The-Secret-History-of-the-…-(2015) either. Will try removing year specification.
# "Looks like Hillarys-America-The-Secret-History-of-the-… doesn't exist on the-numbers.com. Try a google search?"
# Hillarys-America-The-Secret-History-of-the-… seems to be a problem, moving on...
# No luck finding Triple-9-(2018), will try adding -(2017)
# No luck finding Triple-9-(2017), will try adding -(2016)
# No luck finding Triple-9-(2016) either. Will try adding -(2015).
# No luck finding Triple-9-(2015) either. Will try removing year specification.
# Found and stored data for Triple-9!
# No luck finding Light-Between-Oceans-The-(2018), will try adding -(2017)
# No luck finding Light-Between-Oceans-The-(2017), will try adding -(2016)
# No luck finding Light-Between-Oceans-The-(2016) either. Will try adding -(2015).
# No luck finding Light-Between-Oceans-The-(2015) either. Will try removing year specification.
# Found and stored data for Light-Between-Oceans-The!
# No luck finding Dangal-(2018), will try adding -(2017)
# No luck finding Dangal-(2017), will try adding -(2016)
# No luck finding Dangal-(2016) either. Will try adding -(2015).
# No luck finding Dangal-(2015) either. Will try removing year specification.
# "Looks like Dangal doesn't exist on the-numbers.com. Try a google search?"
# Dangal seems to be a problem, moving on...
# No luck finding Fifty-Shades-of-Black-(2018), will try adding -(2017)
# No luck finding Fifty-Shades-of-Black-(2017), will try adding -(2016)
# No luck finding Fifty-Shades-of-Black-(2016) either. Will try adding -(2015).
# No luck finding Fifty-Shades-of-Black-(2015) either. Will try removing year specification.
# Found and stored data for Fifty-Shades-of-Black!
# No luck finding No-Manches-Frida-(2018), will try adding -(2017)
# No luck finding No-Manches-Frida-(2017), will try adding -(2016)
# No luck finding No-Manches-Frida-(2016) either. Will try adding -(2015).
# No luck finding No-Manches-Frida-(2015) either. Will try removing year specification.
# Found and stored data for No-Manches-Frida!
# No luck finding CafÃ©-Society-(2018), will try adding -(2017)
# No luck finding CafÃ©-Society-(2017), will try adding -(2016)
# No luck finding CafÃ©-Society-(2016) either. Will try adding -(2015).
# No luck finding CafÃ©-Society-(2015) either. Will try removing year specification.
# "Looks like CafÃ©-Society doesn't exist on the-numbers.com. Try a google search?"
# CafÃ©-Society seems to be a problem, moving on...
# No luck finding Pride-and-Prejudice-and-Zombies-(2018), will try adding -(2017)
# No luck finding Pride-and-Prejudice-and-Zombies-(2017), will try adding -(2016)
# No luck finding Pride-and-Prejudice-and-Zombies-(2016) either. Will try adding -(2015).
# No luck finding Pride-and-Prejudice-and-Zombies-(2015) either. Will try removing year specification.
# Found and stored data for Pride-and-Prejudice-and-Zombies!
# No luck finding Darkness-The-(2018), will try adding -(2017)
# No luck finding Darkness-The-(2017), will try adding -(2016)
# No luck finding Darkness-The-(2016) either. Will try adding -(2015).
# No luck finding Darkness-The-(2015) either. Will try removing year specification.
# Found and stored data for Darkness-The!
# No luck finding Nocturnal-Animals-(2018), will try adding -(2017)
# No luck finding Nocturnal-Animals-(2017), will try adding -(2016)
# No luck finding Nocturnal-Animals-(2016) either. Will try adding -(2015).
# No luck finding Nocturnal-Animals-(2015) either. Will try removing year specification.
# Found and stored data for Nocturnal-Animals!
# No luck finding Live-by-Night-(2018), will try adding -(2017)
# No luck finding Live-by-Night-(2017), will try adding -(2016)
# No luck finding Live-by-Night-(2016) either. Will try adding -(2015).
# No luck finding Live-by-Night-(2015) either. Will try removing year specification.
# Found and stored data for Live-by-Night!
# No luck finding Lady-in-the-Van-The-(2018), will try adding -(2017)
# No luck finding Lady-in-the-Van-The-(2017), will try adding -(2016)
# No luck finding Lady-in-the-Van-The-(2016) either. Will try adding -(2015).
# No luck finding Lady-in-the-Van-The-(2015) either. Will try removing year specification.
# Found and stored data for Lady-in-the-Van-The!
# No luck finding Perfect-Match-The-(2018), will try adding -(2017)
# No luck finding Perfect-Match-The-(2017), will try adding -(2016)
# No luck finding Perfect-Match-The-(2016) either. Will try adding -(2015).
# No luck finding Perfect-Match-The-(2015) either. Will try removing year specification.
# Found and stored data for Perfect-Match-The!
# No luck finding Popstar-Never-Stop-Never-Stopping-(2018), will try adding -(2017)
# No luck finding Popstar-Never-Stop-Never-Stopping-(2017), will try adding -(2016)
# No luck finding Popstar-Never-Stop-Never-Stopping-(2016) either. Will try adding -(2015).
# No luck finding Popstar-Never-Stop-Never-Stopping-(2015) either. Will try removing year specification.
# Found and stored data for Popstar-Never-Stop-Never-Stopping!
# No luck finding Hardcore-Henry-(2018), will try adding -(2017)
# No luck finding Hardcore-Henry-(2017), will try adding -(2016)
# No luck finding Hardcore-Henry-(2016) either. Will try adding -(2015).
# No luck finding Hardcore-Henry-(2015) either. Will try removing year specification.
# Found and stored data for Hardcore-Henry!
# No luck finding Lobster-The-(2018), will try adding -(2017)
# No luck finding Lobster-The-(2017), will try adding -(2016)
# No luck finding Lobster-The-(2016) either. Will try adding -(2015).
# No luck finding Lobster-The-(2015) either. Will try removing year specification.
# Found and stored data for Lobster-The!
# No luck finding Meet-the-Blacks-(2018), will try adding -(2017)
# No luck finding Meet-the-Blacks-(2017), will try adding -(2016)
# No luck finding Meet-the-Blacks-(2016) either. Will try adding -(2015).
# No luck finding Meet-the-Blacks-(2015) either. Will try removing year specification.
# Found and stored data for Meet-the-Blacks!
# No luck finding Ratchet-and-Clank-(2018), will try adding -(2017)
# No luck finding Ratchet-and-Clank-(2017), will try adding -(2016)
# No luck finding Ratchet-and-Clank-(2016) either. Will try adding -(2015).
# No luck finding Ratchet-and-Clank-(2015) either. Will try removing year specification.
# Found and stored data for Ratchet-and-Clank!
# No luck finding A-Beautiful-Planet-(2018), will try adding -(2017)
# No luck finding A-Beautiful-Planet-(2017), will try adding -(2016)
# No luck finding A-Beautiful-Planet-(2016) either. Will try adding -(2015).
# No luck finding A-Beautiful-Planet-(2015) either. Will try removing year specification.
# "Looks like A-Beautiful-Planet doesn't exist on the-numbers.com. Try a google search?"
# A-Beautiful-Planet seems to be a problem, moving on...
# No luck finding Loving-(2018), will try adding -(2017)
# No luck finding Loving-(2017), will try adding -(2016)
# Found and stored data for Loving-2016!
# No luck finding Silence-(2018), will try adding -(2017)
# No luck finding Silence-(2017), will try adding -(2016)
# Found and stored data for Silence-2016!
# No luck finding Shut-In-(2018), will try adding -(2017)
# No luck finding Shut-In-(2017), will try adding -(2016)
# No luck finding Shut-In-(2016) either. Will try adding -(2015).
# No luck finding Shut-In-(2015) either. Will try removing year specification.
# Found and stored data for Shut-In!
# No luck finding Brothers-Grimsby-The-(2018), will try adding -(2017)
# No luck finding Brothers-Grimsby-The-(2017), will try adding -(2016)
# No luck finding Brothers-Grimsby-The-(2016) either. Will try adding -(2015).
# No luck finding Brothers-Grimsby-The-(2015) either. Will try removing year specification.
# Found and stored data for Brothers-Grimsby-The!
# No luck finding Young-Messiah-The-(2018), will try adding -(2017)
# No luck finding Young-Messiah-The-(2017), will try adding -(2016)
# No luck finding Young-Messiah-The-(2016) either. Will try adding -(2015).
# No luck finding Young-Messiah-The-(2015) either. Will try removing year specification.
# Found and stored data for Young-Messiah-The!
# No luck finding Southside-with-You-(2018), will try adding -(2017)
# No luck finding Southside-with-You-(2017), will try adding -(2016)
# No luck finding Southside-with-You-(2016) either. Will try adding -(2015).
# No luck finding Southside-with-You-(2015) either. Will try removing year specification.
# Found and stored data for Southside-with-You!
# No luck finding Captain-Fantastic-(2018), will try adding -(2017)
# No luck finding Captain-Fantastic-(2017), will try adding -(2016)
# No luck finding Captain-Fantastic-(2016) either. Will try adding -(2015).
# No luck finding Captain-Fantastic-(2015) either. Will try removing year specification.
# Found and stored data for Captain-Fantastic!
# No luck finding 20th-Century-Women-(2018), will try adding -(2017)
# No luck finding 20th-Century-Women-(2017), will try adding -(2016)
# No luck finding 20th-Century-Women-(2016) either. Will try adding -(2015).
# No luck finding 20th-Century-Women-(2015) either. Will try removing year specification.
# Found and stored data for 20th-Century-Women!
# No luck finding Sultan-(2018), will try adding -(2017)
# No luck finding Sultan-(2017), will try adding -(2016)
# Found and stored data for Sultan-2016!
# No luck finding Hunt-for-the-Wilderpeople-(2018), will try adding -(2017)
# No luck finding Hunt-for-the-Wilderpeople-(2017), will try adding -(2016)
# No luck finding Hunt-for-the-Wilderpeople-(2016) either. Will try adding -(2015).
# No luck finding Hunt-for-the-Wilderpeople-(2015) either. Will try removing year specification.
# Found and stored data for Hunt-for-the-Wilderpeople!
# No luck finding Bleed-for-This-(2018), will try adding -(2017)
# No luck finding Bleed-for-This-(2017), will try adding -(2016)
# No luck finding Bleed-for-This-(2016) either. Will try adding -(2015).
# No luck finding Bleed-for-This-(2015) either. Will try removing year specification.
# Found and stored data for Bleed-for-This!
# No luck finding Incarnate-(2018), will try adding -(2017)
# No luck finding Incarnate-(2017), will try adding -(2016)
# No luck finding Incarnate-(2016) either. Will try adding -(2015).
# No luck finding Incarnate-(2015) either. Will try removing year specification.
# Found and stored data for Incarnate!
# No luck finding Absolutely-Fabulous-The-Movie-(2018), will try adding -(2017)
# ...
# 0    January 12th 2018           R           93
# 0    January 12th 2018           R           93
# 0    January 19th 2018           R           81
# 0    January 19th 2018           R           81
# 0    January 12th 2018           R           91
# 0    February 9th 2018           R           99
# 0    February 9th 2018           R           99
# 0    February 9th 2018           R           99
# 0    February 9th 2018           R           99
# 0       March 2nd 2018           R           93
# 0    January 26th 2018       PG-13           93
# 0    January 26th 2018       PG-13           93
# 0    January 26th 2018       PG-13           93
# 0    February 2nd 2018           R           88
# 0    February 2nd 2018           R           88
#
#                                             Franchise  \
# 0                                           Star Wars
# 0                                        Finding Nemo
# 0            Captain AmericaMarvel Cinematic Universe
# 0                                                 NaN
# 0                                                 NaN
# 0                                       X-MenDeadpool
# 0                                                 NaN
# 0      Man of SteelSupermanBatmanDC Extended Universe
# 0                                DC Extended Universe
# 0                                                 NaN
# 0                                                 NaN
# 0   Harry PotterFantastic Beasts and Where to Find...
# 0                           Marvel Cinematic Universe
# 0                                                 NaN
# 0                                              Bourne
# 0                                           Star Trek
# 0                                               X-Men
# 0                                                 NaN
# 0                                                 NaN
# 0                                       Kung Fu Panda
# 0                                        Ghostbusters
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                            Bad Moms
# 0                                                 NaN
# 0                                    Independence Day
# 0                                       The Conjuring
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                Source              Genre  \
# 0                            Spin-Off          Adventure
# 0                 Original Screenplay          Adventure
# 0        Based on Comic/Graphic Novel             Action
# 0                 Original Screenplay          Adventure
# 0   Based on Fiction Book/Short Story          Adventure
# 0        Based on Comic/Graphic Novel             Action
# 0                 Original Screenplay          Adventure
# 0        Based on Comic/Graphic Novel             Action
# 0        Based on Comic/Graphic Novel             Action
# 0                 Original Screenplay          Adventure
# 0                 Original Screenplay            Musical
# 0                            Spin-Off          Adventure
# 0        Based on Comic/Graphic Novel          Adventure
# 0       Based on Factual Book/Article              Drama
# 0   Based on Fiction Book/Short Story             Action
# 0                         Based on TV          Adventure
# 0        Based on Comic/Graphic Novel             Action
# 0                        Based on Toy          Adventure
# 0                 Original Screenplay            Musical
# 0                 Original Screenplay          Adventure
# 0                              Remake             Comedy
# 0                 Original Screenplay             Comedy
# 0   Based on Fiction Book/Short Story          Adventure
# 0       Based on Factual Book/Article              Drama
# 0                 Original Screenplay             Comedy
# 0                       Based on Game          Adventure
# 0                 Original Screenplay             Action
# 0                 Original Screenplay             Horror
# 0   Based on Fiction Book/Short Story              Drama
# 0                 Original Screenplay  Thriller/Suspense
# ..                                ...                ...
# 0   Based on Fiction Book/Short Story  Thriller/Suspense
# 0                 Original Screenplay             Action
# 0                              Remake             Action
# 0   Based on Fiction Book/Short Story              Drama
# 0                 Original Screenplay          Adventure
# 0   Based on Fiction Book/Short Story              Drama
# 0             Based on Religious Text              Drama
# 0             Based on Religious Text              Drama
# 0           Based on Real Life Events          Adventure
# 0           Based on Real Life Events          Adventure
# 0           Based on Real Life Events        Documentary
# 0           Based on Real Life Events        Documentary
# 0           Based on Real Life Events        Documentary
# 0                 Original Screenplay             Action
# 0       Based on Factual Book/Article        Documentary
# 0                 Original Screenplay             Comedy
# 0                 Original Screenplay             Comedy
# 0                 Original Screenplay              Drama
# 0                 Original Screenplay              Drama
# 0                 Original Screenplay             Comedy
# 0   Based on Fiction Book/Short Story             Comedy
# 0   Based on Fiction Book/Short Story             Comedy
# 0   Based on Fiction Book/Short Story             Comedy
# 0   Based on Fiction Book/Short Story             Comedy
# 0                 Original Screenplay             Horror
# 0                 Original Screenplay              Drama
# 0                 Original Screenplay              Drama
# 0                 Original Screenplay              Drama
# 0           Based on Real Life Events            Reality
# 0           Based on Real Life Events            Reality
#
#         Production Method         Creative Type Production Companies  \
# 0   Animation/Live Action       Science Fiction            Lucasfilm
# 0       Digital Animation          Kids Fiction         Disney-Pixar
# 0             Live Action            Super Hero               Marvel
# 0       Digital Animation          Kids Fiction         Illumination
# 0   Animation/Live Action               Fantasy                 Walt
# 0             Live Action            Super Hero               Marvel
# 0       Digital Animation          Kids Fiction                 Walt
# 0             Live Action            Super Hero               Warner
# 0             Live Action            Super Hero               Warner
# 0       Digital Animation          Kids Fiction         Illumination
# 0       Digital Animation          Kids Fiction                 Walt
# 0             Live Action               Fantasy               Warner
# 0             Live Action            Super Hero               Marvel
# 0             Live Action         Dramatization                  Fox
# 0             Live Action  Contemporary Fiction            Universal
# 0             Live Action       Science Fiction               Sneaky
# 0             Live Action            Super Hero            Twentieth
# 0       Digital Animation          Kids Fiction           DreamWorks
# 0             Live Action  Contemporary Fiction              Gilbert
# 0       Digital Animation          Kids Fiction           DreamWorks
# 0             Live Action       Science Fiction             Columbia
# 0             Live Action  Contemporary Fiction                  New
# 0             Live Action    Historical Fiction               Warner
# 0             Live Action         Dramatization              Village
# 0             Live Action  Contemporary Fiction                 Bill
# 0       Digital Animation          Kids Fiction             Columbia
# 0             Live Action       Science Fiction                 20th
# 0             Live Action               Fantasy                  New
# 0             Live Action       Science Fiction            Paramount
# 0             Live Action       Science Fiction             Columbia
# ..                    ...                   ...                  ...
# 0             Live Action  Contemporary Fiction              Chernin
# 0             Live Action  Contemporary Fiction               Screen
# 0             Live Action  Contemporary Fiction  Metro-Goldwyn-Mayer
# 0             Live Action  Contemporary Fiction                   LD
# 0   Stop-Motion Animation          Kids Fiction              Aardman
# 0             Live Action  Contemporary Fiction               Likely
# 0             Live Action         Dramatization                 Pure
# 0             Live Action         Dramatization                 Pure
# 0       Digital Animation         Dramatization             Barajoun
# 0       Digital Animation         Dramatization             Barajoun
# 0             Live Action               Factual                  HBO
# 0             Live Action               Factual                  HBO
# 0             Live Action               Factual                  HBO
# 0             Live Action       Science Fiction                Point
# 0             Live Action               Factual               Arches
# 0             Live Action  Contemporary Fiction               Shout!
# 0             Live Action  Contemporary Fiction               Shout!
# 0             Live Action  Contemporary Fiction                Ridge
# 0             Live Action  Contemporary Fiction                Ridge
# 0             Live Action  Contemporary Fiction                Maven
# 0             Live Action  Contemporary Fiction                Black
# 0             Live Action  Contemporary Fiction                Black
# 0             Live Action  Contemporary Fiction                Black
# 0             Live Action  Contemporary Fiction                Black
# 0             Live Action  Contemporary Fiction        Entertainment
# 0             Live Action  Contemporary Fiction                 2929
# 0             Live Action  Contemporary Fiction                 2929
# 0             Live Action  Contemporary Fiction                 2929
# 0             Live Action               Factual              Lineage
# 0             Live Action               Factual              Lineage
#
#                                  Production Countries
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                FinlandUnited States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# ..                                                ...
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                FranceUnited Kingdom
# 0                                       United States
# 0                           South AfricaUnited States
# 0                           South AfricaUnited States
# 0                    Saudi ArabiaUnited Arab Emirates
# 0                    Saudi ArabiaUnited Arab Emirates
# 0   AustriaCameroonCanadaCape VerdeChadCubaDenmark...
# 0   AustriaCameroonCanadaCape VerdeChadCubaDenmark...
# 0   AustriaCameroonCanadaCape VerdeChadCubaDenmark...
# 0                                       United States
# 0                                              France
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
# 0                                       United States
#
# [408 rows x 18 columns]

# %%
df.to_csv("movie_data")

# %%
# Out:
# No luck finding I-Am-Not-Your-Negro-(2018), will try adding -(2017)
# No luck finding I-Am-Not-Your-Negro-(2017), will try adding -(2016)
# No luck finding I-Am-Not-Your-Negro-(2016) either. Will try adding -(2015).
# No luck finding I-Am-Not-Your-Negro-(2015) either. Will try removing year specification.
# Found and stored data for I-Am-Not-Your-Negro!
# 0                               Domestic Releases  \
# 1  February 3rd 2017 Limited by Magnolia Pictures
#
# 0                             International Releases  \
# 1  April 7th 2017 Wide Spain April 7th 2017 Wide ...
#
# 0                                  Video Release  \
# 1  June 13th 2017 by Magnolia Home Entertainment
#
# 0                                        MPAA Rating Running Time  \
# 1  PG-13 for disturbing violent images thematic m...   95 minutes
#
# 0                               Comparisons  \
# 1  vs IrisCreate your own comparison chart…
#
# 0                                           Keywords  \
# 1  African-American Bigotry Voiceover/Narration P...
#
# 0                     Source        Genre Production Method Creative Type  \
# 1  Based on Real Life Events  Documentary       Live Action       Factual
#
# 0 Production Countries
# 1        United States
